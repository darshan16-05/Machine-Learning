# %%
import pickle
import numpy as np

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'sample_data']

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'pipe.pkl', 'sample_data']

# %%
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# Gives the warning that the model was trained with feature names,
#but prediction data has no feature names code will run but with the warning

# %%
pipe.predict(test_input2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import pandas as pd

input_df = pd.DataFrame(
    [[3, 'male', 22, 1, 0, 725, 'S']],
    columns=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
)

pipe.predict(input_df)
# Out:
# array([0])

# %%
prediction = pipe.predict(input_df)
print("Survived" if prediction == 1 else "Not Survived")
# Out:
# Not Survived

# %%
# !git clone https://github.com/darshan16-05/Machine-Learning.git
# Out:
# Cloning into 'Machine-Learning'...
# ...

# %%
# %cd Machine-Learning
# Out:
# /content/Machine-Learning

# %%
# !cp /content/Predicted-value-by-pickle.ipynb /content/Machine-Learning/
# Out:
# cp: cannot stat '/content/Predicted-value-by-pickle.ipynb': No such file or directory

# %%
# !ls /content/
# Out:
# Machine-Learning  pipe.pkl  sample_data
